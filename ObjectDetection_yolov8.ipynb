# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/MyDrive/ColabNotebooks/yolov8'

# %%
# %cd {ROOT_DIR}
# Out:
# /content/drive/MyDrive/ColabNotebooks/yolov8

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd ultralytics/
# Out:
# /content/drive/MyDrive/ColabNotebooks/yolov8/ultralytics

# %%
# !pip install Ipython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -r requirements.txt

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# %cd {ROOT_DIR}
# Out:
# /content/drive/MyDrive/ColabNotebooks/yolov8

# %%
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.3 source='data/dogs_n_cars.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/ColabNotebooks/yolov8/data/dogs_n_cars.jpg: 640x640 5 persons, 8 cars, 8 dogs, 2 cows, 8.6ms
# Speed: 16.3ms preprocess, 8.6ms inference, 34.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
imgshow(os.path.join(ROOT_DIR, 'runs/detect/predict5/dogs_n_cars.jpg'), width=600)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
